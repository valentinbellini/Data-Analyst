# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Cargar los datos
df = pd.read_csv('data/raw-data.csv', encoding='ISO-8859-1') # Pro-tip: muchos datasets de retail usan este encoding.

# Ver las primeras 5 filas
df.head()
